# %% [raw]
# # Last Updated 2/10/2020

# %%
from __future__ import division
import re
import math

# %%
# Specify the input file. This should be text output from chain.cpp
input_file = open(r"C:/Users/avagnoz/Desktop/AM_Markov_Results/markov_results_211215/output_congressDRAFT2H.txt","r")

# %%
MC_input = []

for line in input_file.readlines():
    MC_input.append(line)

# %%
input_file.close()

# %%
MC_input
# Out:
# ['We have 2260 precincts.\n',
#  'There are 826/2 boundary edges\n',
#  'first p is 0.0913515\n',
#  'first revisitations is 1\n',
#  'A has 1108559 votes\n',
#  'B has 1364749 votes\n',
#  'total population is 5118425\n',
#  'initial variance is 0.0112919\n',
#  'initial median_mean is 0.0378073\n',
#  'initial BG_modified is 0.0336274\n',
#  'initial efficiency_gap is 0.261258\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0043364\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 4194304\n',
#  'total moreunusual/steps is 1/4194305\n',
#  'ep=2.3842e-07\n',
#  'p=0.00069053\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.0046713\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 4194304\n',
#  'total moreunusual/steps is 1/4194305\n',
#  'ep=2.3842e-07\n',
#  'p=0.00069053\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.020413\n',
#  'thread moreunusual is 455298\n',
#  'thread lessunusual is 3739007\n',
#  'total moreunusual/steps is 455298/4194305\n',
#  'ep=0.10855\n',
#  'p=0.46594\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.10358\n',
#  'thread moreunusual is 126766\n',
#  'thread lessunusual is 4067539\n',
#  'total moreunusual/steps is 126766/4194305\n',
#  'ep=0.030223\n',
#  'p=0.24586\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0036908\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 8388609\n',
#  'total moreunusual/steps is 1/8388610\n',
#  'ep=1.1921e-07\n',
#  'p=0.00048828\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.013118\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 8388609\n',
#  'total moreunusual/steps is 1/8388610\n',
#  'ep=1.1921e-07\n',
#  'p=0.00048828\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.024742\n',
#  'thread moreunusual is 778720\n',
#  'thread lessunusual is 7609890\n',
#  'total moreunusual/steps is 778720/8388610\n',
#  'ep=0.092831\n',
#  'p=0.43088\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.11438\n',
#  'thread moreunusual is 210530\n',
#  'thread lessunusual is 8178080\n',
#  'total moreunusual/steps is 210530/8388610\n',
#  'ep=0.025097\n',
#  'p=0.22404\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0038104\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 12582911\n',
#  'total moreunusual/steps is 1/12582912\n',
#  'ep=7.9473e-08\n',
#  'p=0.00039868\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.028245\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 12582911\n',
#  'total moreunusual/steps is 1/12582912\n',
#  'ep=7.9473e-08\n',
#  'p=0.00039868\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.028313\n',
#  'thread moreunusual is 1785549\n',
#  'thread lessunusual is 10797363\n',
#  'total moreunusual/steps is 1785549/12582912\n',
#  'ep=0.1419\n',
#  'p=0.53273\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.10412\n',
#  'thread moreunusual is 250204\n',
#  'thread lessunusual is 12332708\n',
#  'total moreunusual/steps is 250204/12582912\n',
#  'ep=0.019884\n',
#  'p=0.19942\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0032321\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 16777216\n',
#  'total moreunusual/steps is 1/16777217\n',
#  'ep=5.9605e-08\n',
#  'p=0.00034527\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.036828\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 16777216\n',
#  'total moreunusual/steps is 1/16777217\n',
#  'ep=5.9605e-08\n',
#  'p=0.00034527\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.036818\n',
#  'thread moreunusual is 2481620\n',
#  'thread lessunusual is 14295597\n',
#  'total moreunusual/steps is 2481620/16777217\n',
#  'ep=0.14792\n',
#  'p=0.5439\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.39642\n',
#  'thread moreunusual is 358846\n',
#  'thread lessunusual is 16418371\n',
#  'total moreunusual/steps is 358846/16777217\n',
#  'ep=0.021389\n',
#  'p=0.20683\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0050947\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 20971529\n',
#  'total moreunusual/steps is 1/20971530\n',
#  'ep=4.7684e-08\n',
#  'p=0.00030882\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.024702\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 20971529\n',
#  'total moreunusual/steps is 1/20971530\n',
#  'ep=4.7684e-08\n',
#  'p=0.00030882\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.025532\n',
#  'thread moreunusual is 3641095\n',
#  'thread lessunusual is 17330435\n',
#  'total moreunusual/steps is 3641095/20971530\n',
#  'ep=0.17362\n',
#  'p=0.58927\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.11724\n',
#  'thread moreunusual is 581337\n',
#  'thread lessunusual is 20390193\n',
#  'total moreunusual/steps is 581337/20971530\n',
#  'ep=0.02772\n',
#  'p=0.23546\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0034293\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 25165823\n',
#  'total moreunusual/steps is 1/25165824\n',
#  'ep=3.9736e-08\n',
#  'p=0.00028191\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.018309\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 25165823\n',
#  'total moreunusual/steps is 1/25165824\n',
#  'ep=3.9736e-08\n',
#  'p=0.00028191\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.024476\n',
#  'thread moreunusual is 3847836\n',
#  'thread lessunusual is 21317988\n',
#  'total moreunusual/steps is 3847836/25165824\n',
#  'ep=0.1529\n',
#  'p=0.55299\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.2491\n',
#  'thread moreunusual is 592964\n',
#  'thread lessunusual is 24572860\n',
#  'total moreunusual/steps is 592964/25165824\n',
#  'ep=0.023562\n',
#  'p=0.21708\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0027842\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 29360128\n',
#  'total moreunusual/steps is 1/29360129\n',
#  'ep=3.406e-08\n',
#  'p=0.000261\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.020995\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 29360128\n',
#  'total moreunusual/steps is 1/29360129\n',
#  'ep=3.406e-08\n',
#  'p=0.000261\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.032369\n',
#  'thread moreunusual is 5190467\n',
#  'thread lessunusual is 24169662\n',
#  'total moreunusual/steps is 5190467/29360129\n',
#  'ep=0.17679\n',
#  'p=0.59462\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.25423\n',
#  'thread moreunusual is 2105715\n',
#  'thread lessunusual is 27254414\n',
#  'total moreunusual/steps is 2105715/29360129\n',
#  'ep=0.07172\n',
#  'p=0.37874\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0028686\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 33554431\n',
#  'total moreunusual/steps is 1/33554432\n',
#  'ep=2.9802e-08\n',
#  'p=0.00024414\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.0070927\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 33554431\n',
#  'total moreunusual/steps is 1/33554432\n',
#  'ep=2.9802e-08\n',
#  'p=0.00024414\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.018394\n',
#  'thread moreunusual is 6144927\n',
#  'thread lessunusual is 27409505\n',
#  'total moreunusual/steps is 6144927/33554432\n',
#  'ep=0.18313\n',
#  'p=0.6052\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.25122\n',
#  'thread moreunusual is 2746853\n',
#  'thread lessunusual is 30807579\n',
#  'total moreunusual/steps is 2746853/33554432\n',
#  'ep=0.081863\n',
#  'p=0.40463\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0047587\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 37748735\n',
#  'total moreunusual/steps is 1/37748736\n',
#  'ep=2.6491e-08\n',
#  'p=0.00023018\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.00044495\n',
#  'thread moreunusual is 1183\n',
#  'thread lessunusual is 37747553\n',
#  'total moreunusual/steps is 1183/37748736\n',
#  'ep=3.1339e-05\n',
#  'p=0.0079169\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.021247\n',
#  'thread moreunusual is 6144927\n',
#  'thread lessunusual is 31603809\n',
#  'total moreunusual/steps is 6144927/37748736\n',
#  'ep=0.16278\n',
#  'p=0.57059\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.11258\n',
#  'thread moreunusual is 3284149\n',
#  'thread lessunusual is 34464587\n',
#  'total moreunusual/steps is 3284149/37748736\n',
#  'ep=0.087\n',
#  'p=0.41713\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0040168\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 41943040\n',
#  'total moreunusual/steps is 1/41943041\n',
#  'ep=2.3842e-08\n',
#  'p=0.00021837\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is 0.0072435\n',
#  'thread moreunusual is 2772\n',
#  'thread lessunusual is 41940269\n',
#  'total moreunusual/steps is 2772/41943041\n',
#  'ep=6.609e-05\n',
#  'p=0.011497\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.023407\n',
#  'thread moreunusual is 6149197\n',
#  'thread lessunusual is 35793844\n',
#  'total moreunusual/steps is 6149197/41943041\n',
#  'ep=0.14661\n',
#  'p=0.54149\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is -0.034609\n',
#  'thread moreunusual is 3372009\n',
#  'thread lessunusual is 38571032\n',
#  'total moreunusual/steps is 3372009/41943041\n',
#  'ep=0.080395\n',
#  'p=0.40099\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0031444\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 46137343\n',
#  'total moreunusual/steps is 1/46137344\n',
#  'ep=2.1674e-08\n',
#  'p=0.0002082\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.01021\n',
#  'thread moreunusual is 2772\n',
#  'thread lessunusual is 46134572\n',
#  'total moreunusual/steps is 2772/46137344\n',
#  'ep=6.0081e-05\n',
#  'p=0.010962\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.021076\n',
#  'thread moreunusual is 6227651\n',
#  'thread lessunusual is 39909693\n',
#  'total moreunusual/steps is 6227651/46137344\n',
#  'ep=0.13498\n',
#  'p=0.51958\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.10941\n',
#  'thread moreunusual is 3424242\n',
#  'thread lessunusual is 42713102\n',
#  'total moreunusual/steps is 3424242/46137344\n',
#  'ep=0.074218\n',
#  'p=0.38528\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.004406\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 50331647\n',
#  'total moreunusual/steps is 1/50331648\n',
#  'ep=1.9868e-08\n',
#  'p=0.00019934\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is 0.0017\n',
#  'thread moreunusual is 2772\n',
#  'thread lessunusual is 50328876\n',
#  'total moreunusual/steps is 2772/50331648\n',
#  'ep=5.5075e-05\n',
#  'p=0.010495\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.024174\n',
#  'thread moreunusual is 6712155\n',
#  'thread lessunusual is 43619493\n',
#  'total moreunusual/steps is 6712155/50331648\n',
#  'ep=0.13336\n',
#  'p=0.51645\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.11221\n',
#  'thread moreunusual is 3528686\n',
#  'thread lessunusual is 46802962\n',
#  'total moreunusual/steps is 3528686/50331648\n',
#  'ep=0.070109\n',
#  'p=0.37446\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0015055\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 54525951\n',
#  'total moreunusual/steps is 1/54525952\n',
#  'ep=1.834e-08\n',
#  'p=0.00019152\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.0015045\n',
#  'thread moreunusual is 21858\n',
#  'thread lessunusual is 54504094\n',
#  'total moreunusual/steps is 21858/54525952\n',
#  'ep=0.00040087\n',
#  'p=0.028315\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.020652\n',
#  'thread moreunusual is 6986576\n',
#  'thread lessunusual is 47539376\n',
#  'total moreunusual/steps is 6986576/54525952\n',
#  'ep=0.12813\n',
#  'p=0.50623\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.25255\n',
#  'thread moreunusual is 3617714\n',
#  'thread lessunusual is 50908238\n',
#  'total moreunusual/steps is 3617714/54525952\n',
#  'ep=0.066348\n',
#  'p=0.36428\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.004325\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 58720258\n',
#  'total moreunusual/steps is 1/58720259\n',
#  'ep=1.703e-08\n',
#  'p=0.00018455\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.040933\n',
#  'thread moreunusual is 25677\n',
#  'thread lessunusual is 58694582\n',
#  'total moreunusual/steps is 25677/58720259\n',
#  'ep=0.00043728\n',
#  'p=0.029573\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.030453\n',
#  'thread moreunusual is 7185203\n',
#  'thread lessunusual is 51535056\n',
#  'total moreunusual/steps is 7185203/58720259\n',
#  'ep=0.12236\n',
#  'p=0.4947\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.10708\n',
#  'thread moreunusual is 3642430\n',
#  'thread lessunusual is 55077829\n',
#  'total moreunusual/steps is 3642430/58720259\n',
#  'ep=0.06203\n',
#  'p=0.35222\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0042644\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 62914559\n',
#  'total moreunusual/steps is 1/62914560\n',
#  'ep=1.5895e-08\n',
#  'p=0.0001783\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is 0.014477\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 62887226\n',
#  'total moreunusual/steps is 27334/62914560\n',
#  'ep=0.00043446\n',
#  'p=0.029478\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.019467\n',
#  'thread moreunusual is 7542397\n',
#  'thread lessunusual is 55372163\n',
#  'total moreunusual/steps is 7542397/62914560\n',
#  'ep=0.11988\n',
#  'p=0.48966\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.1225\n',
#  'thread moreunusual is 3683899\n',
#  'thread lessunusual is 59230661\n',
#  'total moreunusual/steps is 3683899/62914560\n',
#  'ep=0.058554\n',
#  'p=0.34221\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0036521\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 67108866\n',
#  'total moreunusual/steps is 1/67108867\n',
#  'ep=1.4901e-08\n',
#  'p=0.00017263\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.037242\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 67081533\n',
#  'total moreunusual/steps is 27334/67108867\n',
#  'ep=0.00040731\n',
#  'p=0.028541\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.033794\n',
#  'thread moreunusual is 7741873\n',
#  'thread lessunusual is 59366994\n',
#  'total moreunusual/steps is 7741873/67108867\n',
#  'ep=0.11536\n',
#  'p=0.48034\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.24531\n',
#  'thread moreunusual is 3722549\n',
#  'thread lessunusual is 63386318\n',
#  'total moreunusual/steps is 3722549/67108867\n',
#  'ep=0.05547\n',
#  'p=0.33308\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0040018\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 71303169\n',
#  'total moreunusual/steps is 1/71303170\n',
#  'ep=1.4025e-08\n',
#  'p=0.00016748\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.019035\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 71275836\n',
#  'total moreunusual/steps is 27334/71303170\n',
#  'ep=0.00038335\n',
#  'p=0.027689\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.031671\n',
#  'thread moreunusual is 9039031\n',
#  'thread lessunusual is 62264139\n',
#  'total moreunusual/steps is 9039031/71303170\n',
#  'ep=0.12677\n',
#  'p=0.50353\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.10779\n',
#  'thread moreunusual is 4056002\n',
#  'thread lessunusual is 67247168\n',
#  'total moreunusual/steps is 4056002/71303170\n',
#  'ep=0.056884\n',
#  'p=0.33729\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0035994\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 75497472\n',
#  'total moreunusual/steps is 1/75497473\n',
#  'ep=1.3245e-08\n',
#  'p=0.00016276\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.014641\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 75470139\n',
#  'total moreunusual/steps is 27334/75497473\n',
#  'ep=0.00036205\n',
#  'p=0.026909\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.027949\n',
#  'thread moreunusual is 9384618\n',
#  'thread lessunusual is 66112855\n',
#  'total moreunusual/steps is 9384618/75497473\n',
#  'ep=0.1243\n',
#  'p=0.49861\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.24781\n',
#  'thread moreunusual is 4202487\n',
#  'thread lessunusual is 71294986\n',
#  'total moreunusual/steps is 4202487/75497473\n',
#  'ep=0.055664\n',
#  'p=0.33366\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0028821\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 79691777\n',
#  'total moreunusual/steps is 1/79691778\n',
#  'ep=1.2548e-08\n',
#  'p=0.00015842\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.023688\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 79664444\n',
#  'total moreunusual/steps is 27334/79691778\n',
#  'ep=0.000343\n',
#  'p=0.026191\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.031446\n',
#  'thread moreunusual is 10086532\n',
#  'thread lessunusual is 69605246\n',
#  'total moreunusual/steps is 10086532/79691778\n',
#  'ep=0.12657\n',
#  'p=0.50313\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.25754\n',
#  'thread moreunusual is 4442792\n',
#  'thread lessunusual is 75248986\n',
#  'total moreunusual/steps is 4442792/79691778\n',
#  'ep=0.05575\n',
#  'p=0.33392\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0043376\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 83886081\n',
#  'total moreunusual/steps is 1/83886082\n',
#  'ep=1.1921e-08\n',
#  'p=0.00015441\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.0077619\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 83858748\n',
#  'total moreunusual/steps is 27334/83886082\n',
#  'ep=0.00032585\n',
#  'p=0.025528\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.031696\n',
#  'thread moreunusual is 10925252\n',
#  'thread lessunusual is 72960830\n',
#  'total moreunusual/steps is 10925252/83886082\n',
#  'ep=0.13024\n',
#  'p=0.51037\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is -0.023476\n',
#  'thread moreunusual is 5179426\n',
#  'thread lessunusual is 78706656\n',
#  'total moreunusual/steps is 5179426/83886082\n',
#  'ep=0.061744\n',
#  'p=0.35141\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0039249\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 88080385\n',
#  'total moreunusual/steps is 1/88080386\n',
#  'ep=1.1353e-08\n',
#  'p=0.00015069\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.02196\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 88053052\n',
#  'total moreunusual/steps is 27334/88080386\n',
#  'ep=0.00031033\n',
#  'p=0.024913\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.031786\n',
#  'thread moreunusual is 11572438\n',
#  'thread lessunusual is 76507948\n',
#  'total moreunusual/steps is 11572438/88080386\n',
#  'ep=0.13138\n',
#  'p=0.51261\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.25207\n',
#  'thread moreunusual is 5535854\n',
#  'thread lessunusual is 82544532\n',
#  'total moreunusual/steps is 5535854/88080386\n',
#  'ep=0.06285\n',
#  'p=0.35454\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0045426\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 92274689\n',
#  'total moreunusual/steps is 1/92274690\n',
#  'ep=1.0837e-08\n',
#  'p=0.00014722\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.025935\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 92247356\n',
#  'total moreunusual/steps is 27334/92274690\n',
#  'ep=0.00029622\n',
#  'p=0.02434\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.026517\n',
#  'thread moreunusual is 11935168\n',
#  'thread lessunusual is 80339522\n',
#  'total moreunusual/steps is 11935168/92274690\n',
#  'ep=0.12934\n',
#  'p=0.50861\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.24952\n',
#  'thread moreunusual is 5971795\n',
#  'thread lessunusual is 86302895\n',
#  'total moreunusual/steps is 5971795/92274690\n',
#  'ep=0.064718\n',
#  'p=0.35977\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0042884\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 96468991\n',
#  'total moreunusual/steps is 1/96468992\n',
#  'ep=1.0366e-08\n',
#  'p=0.00014399\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.030017\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 96441658\n',
#  'total moreunusual/steps is 27334/96468992\n',
#  'ep=0.00028334\n',
#  'p=0.023805\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.024589\n',
#  'thread moreunusual is 11999691\n',
#  'thread lessunusual is 84469301\n',
#  'total moreunusual/steps is 11999691/96468992\n',
#  'ep=0.12439\n',
#  'p=0.49878\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.10989\n',
#  'thread moreunusual is 6009179\n',
#  'thread lessunusual is 90459813\n',
#  'total moreunusual/steps is 6009179/96468992\n',
#  'ep=0.062291\n',
#  'p=0.35296\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0032954\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 100663296\n',
#  'total moreunusual/steps is 1/100663297\n',
#  'ep=9.9341e-09\n',
#  'p=0.00014095\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.015765\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 100635963\n',
#  'total moreunusual/steps is 27334/100663297\n',
#  'ep=0.00027154\n',
#  'p=0.023304\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.027101\n',
#  'thread moreunusual is 11999691\n',
#  'thread lessunusual is 88663606\n',
#  'total moreunusual/steps is 11999691/100663297\n',
#  'ep=0.11921\n',
#  'p=0.48827\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.26616\n',
#  'thread moreunusual is 6038817\n',
#  'thread lessunusual is 94624480\n',
#  'total moreunusual/steps is 6038817/100663297\n',
#  'ep=0.05999\n',
#  'p=0.34638\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0022982\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 104857599\n',
#  'total moreunusual/steps is 1/104857600\n',
#  'ep=9.5367e-09\n',
#  'p=0.00013811\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.0048646\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 104830266\n',
#  'total moreunusual/steps is 27334/104857600\n',
#  'ep=0.00026068\n',
#  'p=0.022833\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.020877\n',
#  'thread moreunusual is 12071419\n',
#  'thread lessunusual is 92786181\n',
#  'total moreunusual/steps is 12071419/104857600\n',
#  'ep=0.11512\n',
#  'p=0.47984\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.25013\n',
#  'thread moreunusual is 6858793\n',
#  'thread lessunusual is 97998807\n',
#  'total moreunusual/steps is 6858793/104857600\n',
#  'ep=0.065411\n',
#  'p=0.36169\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0031396\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 109051903\n',
#  'total moreunusual/steps is 1/109051904\n',
#  'ep=9.1699e-09\n',
#  'p=0.00013542\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.014767\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 109024570\n',
#  'total moreunusual/steps is 27334/109051904\n',
#  'ep=0.00025065\n',
#  'p=0.02239\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.019809\n',
#  'thread moreunusual is 12260149\n',
#  'thread lessunusual is 96791755\n',
#  'total moreunusual/steps is 12260149/109051904\n',
#  'ep=0.11242\n',
#  'p=0.47418\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.25374\n',
#  'thread moreunusual is 8345333\n',
#  'thread lessunusual is 100706571\n',
#  'total moreunusual/steps is 8345333/109051904\n',
#  'ep=0.076526\n',
#  'p=0.39122\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0033316\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 113246208\n',
#  'total moreunusual/steps is 1/113246209\n',
#  'ep=8.8303e-09\n',
#  'p=0.00013289\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.013321\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 113218875\n',
#  'total moreunusual/steps is 27334/113246209\n',
#  'ep=0.00024137\n',
#  'p=0.021971\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.023769\n',
#  'thread moreunusual is 12546630\n',
#  'thread lessunusual is 100699579\n',
#  'total moreunusual/steps is 12546630/113246209\n',
#  'ep=0.11079\n',
#  'p=0.47072\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.2605\n',
#  'thread moreunusual is 8838652\n',
#  'thread lessunusual is 104407557\n',
#  'total moreunusual/steps is 8838652/113246209\n',
#  'ep=0.078048\n',
#  'p=0.39509\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0034128\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 117440511\n',
#  'total moreunusual/steps is 1/117440512\n',
#  'ep=8.5149e-09\n',
#  'p=0.0001305\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.042079\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 117413178\n',
#  'total moreunusual/steps is 27334/117440512\n',
#  'ep=0.00023275\n',
#  'p=0.021575\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.030465\n',
#  'thread moreunusual is 12904034\n',
#  'thread lessunusual is 104536478\n',
#  'total moreunusual/steps is 12904034/117440512\n',
#  'ep=0.10988\n',
#  'p=0.46878\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.24893\n',
#  'thread moreunusual is 9116589\n',
#  'thread lessunusual is 108323923\n',
#  'total moreunusual/steps is 9116589/117440512\n',
#  'ep=0.077627\n',
#  'p=0.39402\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0037005\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 121634819\n',
#  'total moreunusual/steps is 1/121634820\n',
#  'ep=8.2213e-09\n',
#  'p=0.00012823\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.0050055\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 121607486\n',
#  'total moreunusual/steps is 27334/121634820\n',
#  'ep=0.00022472\n',
#  'p=0.0212\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.022791\n',
#  'thread moreunusual is 13270051\n',
#  'thread lessunusual is 108364769\n',
#  'total moreunusual/steps is 13270051/121634820\n',
#  'ep=0.1091\n',
#  'p=0.46711\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.12368\n',
#  'thread moreunusual is 9896582\n',
#  'thread lessunusual is 111738238\n',
#  'total moreunusual/steps is 9896582/121634820\n',
#  'ep=0.081363\n',
#  'p=0.40339\n',
#  '\n',
#  'Thread 0 reporting\n',
#  '--FOR VARIANCE--\n',
#  'current variance is 0.0035368\n',
#  'thread moreunusual is 1\n',
#  'thread lessunusual is 125829119\n',
#  'total moreunusual/steps is 1/125829120\n',
#  'ep=7.9473e-09\n',
#  'p=0.00012607\n',
#  '\n',
#  '--FOR MEDIAN/MEAN--\n',
#  'current median_mean is -0.023898\n',
#  'thread moreunusual is 27334\n',
#  'thread lessunusual is 125801786\n',
#  'total moreunusual/steps is 27334/125829120\n',
#  'ep=0.00021723\n',
#  'p=0.020844\n',
#  '\n',
#  '--FOR B_G MODIFIED--\n',
#  'current BG_modified is 0.036944\n',
#  'thread moreunusual is 14068781\n',
#  'thread lessunusual is 111760339\n',
#  'total moreunusual/steps is 14068781/125829120\n',
#  'ep=0.11181\n',
#  'p=0.47288\n',
#  '\n',
#  '--FOR Efficiency Gap--\n',
#  'current efficiency_gap is 0.10778\n',
#  'thread moreunusual is 10585631\n',
#  'thread lessunusual is 115243489\n',
#  'total moreunusual/steps is 10585631/125829120\n',
#  'ep=0.084127\n',
#  'p=0.41019\n',
#  ...]

# %%
#for line in MC_input:
#    print line

# %%
# Value, More Unusual, Less Unusual, Steps Taken, Epsilon, p-value

# Create step/iteration counters.
k_mm = 0
k_v = 0
k_eg = 0
k_pb = 0
k_bgu = 0
k_bgm = 0

# Create boolean flags for which tests are being used.
test_median_mean = False
test_variance = False
test_efficiency_gap = False
test_partisan_bias = False
test_BG_uniform = False
test_BG_modified = False

# Create a variable that specifies which bias measure at which we are currently looking.
Current_Test = None
# Possible Values: 'Median_Mean', 'Variance', 'Efficiency_Gap', 'Partisan_Bias', 'BG_Uniform', 'BG_Modified'

for line in MC_input:
    # BASE CASE: INITIAL OUTPUT
    # Nesting things within the INITIAL check is more efficient.
    if re.match(r'initial',line):
        # Determine which initial output is given.
        
        if re.match(r'initial median_mean',line):
            # Note that we are using this bias measure.
            test_median_mean = True
            # Create the data frame I need.
            MC_Median_Mean = list()
            # Find the index where the value is in the line.
            idx = re.match(r'initial median_mean is ',line).end()
            # Make sure we're looking at the value and not the space before it.
            assert(line[idx]!=' ') # Kind of unneccessary but I'm paranoid.
            # Store the current value.
            current_value = -float(line[idx:-1])
            # Initialize not applicable values.
            thread_moreunusual=None
            thread_lessunusual=None
            steps=0
            ep=None
            p=None
            # Append the first line to the correct data frame.
            MC_Median_Mean.append([current_value,thread_moreunusual,thread_lessunusual,steps,ep,p])
            
        elif re.match(r'initial variance',line):
            test_variance = True
            MC_Variance = list()
            idx = re.match(r'initial variance is ',line).end()
            assert(line[idx]!=' ')
            current_value = float(line[idx:-1])
            assert(len(MC_Variance)==0)
            thread_moreunusual=None
            thread_lessunusual=None
            steps=0
            ep=None
            p=None
            MC_Variance.append([current_value,thread_moreunusual,thread_lessunusual,steps,ep,p])
            
        elif re.match(r'initial efficiency_gap',line):
            test_efficiency_gap = True
            MC_Efficiency_Gap = list()
            idx = re.match(r'initial efficiency_gap is ',line).end()
            assert(line[idx]!=' ')
            current_value = float(line[idx:-1])
            assert(len(MC_Efficiency_Gap)==0)
            thread_moreunusual=None
            thread_lessunusual=None
            steps=0
            ep=None
            p=None
            MC_Efficiency_Gap.append([current_value,thread_moreunusual,thread_lessunusual,steps,ep,p])
            
        elif re.match(r'initial partisan_bias',line):
            test_partisan_bias = True
            MC_Partisan_Bias = list()
            idx = re.match(r'initial partisan_bias is ',line).end()
            assert(line[idx]!=' ')
            current_value = float(line[idx:-1])
            assert(len(MC_Partisan_Bias)==0)
            thread_moreunusual=None
            thread_lessunusual=None
            steps=0
            ep=None
            p=None
            MC_Partisan_Bias.append([current_value,thread_moreunusual,thread_lessunusual,steps,ep,p])
        
        elif re.match(r'initial BG_uniform',line):
            test_BG_uniform = True
            MC_BG_Uniform = list()
            idx = re.match(r'initial BG_uniform is ',line).end()
            assert(line[idx]!=' ')
            current_value = float(line[idx:-1])
            assert(len(MC_BG_Uniform)==0)
            thread_moreunusual=None
            thread_lessunusual=None
            steps=0
            ep=None
            p=None
            MC_BG_Uniform.append([current_value,thread_moreunusual,thread_lessunusual,steps,ep,p])
        
        elif re.match(r'initial BG_modified',line):
            test_BG_modified = True
            MC_BG_Modified = list()
            idx = re.match(r'initial BG_modified is ',line).end()
            assert(line[idx]!=' ')
            current_value = float(line[idx:-1])
            assert(len(MC_BG_Modified)==0)
            thread_moreunusual=None
            thread_lessunusual=None
            steps=0
            ep=None
            p=None
            MC_BG_Modified.append([current_value,thread_moreunusual,thread_lessunusual,steps,ep,p])
            
        else:
            raise Exception('Error: Unknown partisan bias measure used!')

    #####################################################################################################
            
    # IF WE HIT THE START OF AN ANALYSIS BLOCK
    # Analysis blocks include all specified measures for that step of the chain.
    elif re.match(r'Thread 0 reporting',line):
        # For the appropriate tests...
        if test_median_mean == True:
            # If we've only recorded the initial data, do nothing.
            if k_mm == 0:
                pass
            # If we've looked at a new analysis block, then add it to the appropriate data frame.
            elif k_mm > 0:
                MC_Median_Mean.append([current_mm,moreunusual_mm,lessunusual_mm,steps_mm,ep_mm,p_mm])
        if test_variance == True:
            if k_v == 0:
                pass
            elif k_v >0:
                MC_Variance.append([current_v,moreunusual_v,lessunusual_v,steps_v,ep_v,p_v])
        if test_efficiency_gap == True:
            if k_eg == 0:
                pass
            elif k_eg > 0:
                MC_Efficiency_Gap.append([current_eg,moreunusual_eg,lessunusual_eg,steps_eg,ep_eg,p_eg])
        if test_partisan_bias == True: 
            if k_pb == 0:
                pass
            elif k_pb > 0:
                MC_Partisan_Bias.append([current_pb,moreunusual_pb,lessunusual_pb,steps_pb,ep_pb,p_pb])
        if test_BG_uniform == True:
            # If we've only recorded the initial data, do nothing.
            if k_bgu == 0:
                pass
            # If we've looked at a new analysis block, then add it to the appropriate data frame.
            elif k_bgu > 0:
                MC_BG_Uniform.append([current_bgu,moreunusual_bgu,lessunusual_bgu,steps_bgu,ep_bgu,p_bgu])
        if test_BG_modified == True:
            # If we've only recorded the initial data, do nothing.
            if k_bgm == 0:
                pass
            # If we've looked at a new analysis block, then add it to the appropriate data frame.
            elif k_bgm > 0:
                MC_BG_Modified.append([current_bgm,moreunusual_bgm,lessunusual_bgm,steps_bgm,ep_bgm,p_bgm])
        # Note: It's okay that we're not appending the very last values of the chain (after the last
        # "Thread 0 Reporting" line) because they are repeats anyway.
    
    #####################################################################################################
    
    # IF WE HIT A BIAS MEASURE HEADER
    elif re.match(r'--FOR',line):
        if re.match(r'--FOR MEDIAN/MEAN--',line):
            Current_Test = 'Median_Mean'
        elif re.match(r'--FOR VARIANCE--',line):
            Current_Test = 'Variance'
        elif re.match(r'--FOR Efficiency Gap--',line):
            Current_Test = 'Efficiency_Gap'
        elif re.match(r'--FOR PARTISAN_BIAS--',line):
            Current_Test = 'Partisan_Bias'
        elif re.match(r'--FOR B_G UNIFORM--',line):
            Current_Test = 'BG_Uniform'
        elif re.match(r'--FOR B_G MODIFIED--',line):
            Current_Test = 'BG_Modified'
        else:
            raise Exception('Error: Unknown partisan bias measure used!')

    #####################################################################################################
            
    # CURRENT VALUE
    elif re.match(r'current',line):
        if re.match(r'current median_mean is ',line) and Current_Test == 'Median_Mean':
            idx = re.match(r'current median_mean is ',line).end()
            assert(line[idx]!=' ')
            current_mm = -float(line[idx:-1])
        elif re.match(r'current variance is ',line) and Current_Test == 'Variance':
            idx = re.match(r'current variance is ',line).end()
            assert(line[idx]!=' ')
            current_v = float(line[idx:-1])            
        elif re.match(r'current efficiency_gap is ',line) and Current_Test == 'Efficiency_Gap':
            idx = re.match(r'current efficiency_gap is ',line).end()
            assert(line[idx]!=' ')
            current_eg = float(line[idx:-1])  
        elif re.match(r'current partisan_bias is ', line) and Current_Test == 'Partisan_Bias':
            idx = re.match(r'current partisan_bias is ',line).end()
            assert(line[idx]!=' ')
            current_pb = float(line[idx:-1])  
        elif re.match(r'current BG_uniform is ', line) and Current_Test == 'BG_Uniform':
            idx = re.match(r'current BG_uniform is ',line).end()
            assert(line[idx]!=' ')
            current_bgu = float(line[idx:-1])  
        elif re.match(r'current BG_modified is ', line) and Current_Test == 'BG_Modified':
            idx = re.match(r'current BG_modified is ',line).end()
            assert(line[idx]!=' ')
            current_bgm = float(line[idx:-1])  
        else:
            raise Exception('Error: Unknown partisan bias measure used!')

    #####################################################################################################

    # THREAD MOREUNUSUAL
    elif re.match(r'thread moreunusual',line):
        idx = re.match(r'thread moreunusual is ',line).end()
        if Current_Test == 'Median_Mean':
            moreunusual_mm = int(line[idx:-1])
        elif Current_Test == 'Variance':
            moreunusual_v = int(line[idx:-1])
        elif Current_Test == 'Efficiency_Gap':
            moreunusual_eg = int(line[idx:-1])
        elif Current_Test == 'Partisan_Bias':
            moreunusual_pb = int(line[idx:-1])
        elif Current_Test == 'BG_Uniform':
            moreunusual_bgu = int(line[idx:-1])
        elif Current_Test == 'BG_Modified':
            moreunusual_bgm = int(line[idx:-1])
        else:
            raise Exception('Error: Unknown partisan bias measure used!')
    
    #####################################################################################################
    
    # THREAD LESSUNUSUAL
    elif re.match(r'thread lessunusual',line):
        idx = re.match(r'thread lessunusual is ',line).end()
        if Current_Test == 'Median_Mean':
            lessunusual_mm = int(line[idx:-1])
            steps_mm = moreunusual_mm + lessunusual_mm
        elif Current_Test == 'Variance':
            lessunusual_v = int(line[idx:-1])
            steps_v = moreunusual_v + lessunusual_v
        elif Current_Test == 'Efficiency_Gap':
            lessunusual_eg = int(line[idx:-1])
            steps_eg = moreunusual_eg + lessunusual_eg
        elif Current_Test == 'Partisan_Bias':
            lessunusual_pb = int(line[idx:-1])
            steps_pb = moreunusual_pb + lessunusual_pb
        elif Current_Test == 'BG_Uniform':
            lessunusual_bgu = int(line[idx:-1])
            steps_bgu = moreunusual_bgu + lessunusual_bgu
        elif Current_Test == 'BG_Modified':
            lessunusual_bgm = int(line[idx:-1])
            steps_bgm = moreunusual_bgm + lessunusual_bgm
        else:
            raise Exception('Error: Unknown partisan bias measure used!')
        
    #####################################################################################################
    
    # EPSILON
    elif re.match(r'ep=',line):
        idx = re.match(r'ep=',line).end()
        if Current_Test == 'Median_Mean':
            ep_mm = float(line[idx:-1])
        elif Current_Test == 'Variance':
            ep_v = float(line[idx:-1])
        elif Current_Test == 'Efficiency_Gap':
            ep_eg = float(line[idx:-1])
        elif Current_Test == 'Partisan_Bias':
            ep_pb = float(line[idx:-1])
        elif Current_Test == 'BG_Uniform':
            ep_bgu = float(line[idx:-1])
        elif Current_Test == 'BG_Modified':
            ep_bgm = float(line[idx:-1])
        else:
            raise Exception('Error: Unknown partisan bias measure used!')
        
    #####################################################################################################    
               
    # P-VALUE
    elif re.match(r'p=',line):
        idx = re.match(r'p=',line).end()
        if Current_Test == 'Median_Mean':
            p_mm = float(line[idx:-1])
            # When you've gotten to the p-value, you've reached the end of an analysis sub-block.
            # You can increase the counter now.
            k_mm = k_mm + 1
        elif Current_Test == 'Variance':
            p_v = float(line[idx:-1])
            k_v = k_v + 1
        elif Current_Test == 'Efficiency_Gap':
            p_eg = float(line[idx:-1])
            k_eg = k_eg + 1
        elif Current_Test == 'Partisan_Bias':
            p_pb = float(line[idx:-1])
            k_pb = k_pb + 1
        elif Current_Test == 'BG_Uniform':
            p_bgu = float(line[idx:-1])
            k_bgu = k_bgu + 1
        elif Current_Test == 'BG_Modified':
            p_bgm = float(line[idx:-1])
            k_bgm = k_bgm + 1
        else:
            raise Exception('Error: Unknown partisan bias measure used!')
    
    # IF THE LINE IS ANYTHING ELSE, IT'S NOT IMPORTANT
    else:
        pass

# %%
## Calculate descriptive statistics for a sample of maps produced.

# %matplotlib inline
import matplotlib.pyplot as plt

print("----------------- DESCRIPTIVE STATISTICS -----------------")

### MEDIAN MEAN ###
if test_median_mean == True:
    # MEAN
    sum_MM = 0
    sumsq_MM = 0
    MM_pts = list()
    for line in MC_Median_Mean:
        MM_pts.append(line[0])
        sum_MM += line[0]
        sumsq_MM += line[0]**2
    n = len(MC_Median_Mean)
    stat_MM_mean = sum_MM / n
    # STANDARD DEVIATION
    stat_MM_sdev = math.sqrt((sumsq_MM - (sum_MM**2)/n)/(n-1))
    # Z-SCORE
    z_MM = (MC_Median_Mean[0][0]-stat_MM_mean)/stat_MM_sdev
    
    print("n = " + str(n))
    print("Initial Median-Mean Score: " + str(MC_Median_Mean[0][0]))
    print("Average Median-Mean Score: " + str(stat_MM_mean))
    print("Standard Deviation Median-Mean Score: " + str(stat_MM_sdev))
    print("z-score = " + str(z_MM))
    
    plt.hist(MM_pts,bins=15)
    plt.title('Median-Mean Histogram')
    plt.axvline(MC_Median_Mean[0][0], color='r', linewidth=1)
    plt.show()

    print("----------------------------------------------------------")

### VARIANCE ###
# Q: Does it makes sense to look at the variance of the variance scores?
if test_variance == True:
    # MEAN
    sum_VAR = 0
    sumsq_VAR = 0
    VAR_pts = list()
    for line in MC_Variance:
        VAR_pts.append(line[0])
        sum_VAR += line[0]
        sumsq_VAR += line[0]**2
    n = len(MC_Variance)
    stat_VAR_mean = sum_VAR / n
    # STANDARD DEVIATION
    stat_VAR_sdev = math.sqrt((sumsq_VAR - (sum_VAR**2)/n)/(n-1))
    # Z-SCORE
    z_VAR = (MC_Variance[0][0]-stat_VAR_mean)/stat_VAR_sdev
    
    print("n = " + str(n))
    print("Initial Variance: " + str(MC_Variance[0][0]))
    print("Average Variance Score: " + str(stat_VAR_mean))
    print("Standard Deviation Variance Score: " + str(stat_VAR_sdev))
    print("z-score = " + str(z_VAR))
    
    plt.hist(VAR_pts,bins=15)
    plt.title('Variance Histogram')
    plt.axvline(MC_Variance[0][0], color='r', linewidth=1)
    plt.show()

    print("----------------------------------------------------------")

### EFFICIENCY GAP ###
if test_efficiency_gap == True:
    # MEAN
    sum_EG = 0
    sumsq_EG = 0
    EG_pts = list()
    for line in MC_Efficiency_Gap:
        EG_pts.append(line[0])
        sum_EG += line[0]
        sumsq_EG += line[0]**2
    n = len(MC_Efficiency_Gap)
    stat_EG_mean = sum_EG / n
    # STANDARD DEVIATION
    stat_EG_sdev = math.sqrt((sumsq_EG - (sum_EG**2)/n)/(n-1))
    # Z-SCORE
    z_EG = (MC_Efficiency_Gap[0][0]-stat_EG_mean)/stat_EG_sdev
    
    print("n = " + str(n))
    print("Initial Effidiency Gap: " + str(MC_Efficiency_Gap[0][0]))
    print("Average Efficiency Gap Score: " + str(stat_EG_mean))
    print("Standard Deviation Efficiency Gap Score: " + str(stat_EG_sdev))
    print("z-score = " + str(z_EG))
    
    plt.hist(EG_pts,bins=15)
    plt.title('Efficiency Gap Histogram')
    plt.axvline(MC_Efficiency_Gap[0][0], color='r', linewidth=1)
    plt.show()
    
    print("----------------------------------------------------------")

### PARTISAN BIAS ###
if test_partisan_bias == True:
    # MEAN
    sum_PB = 0
    sumsq_PB = 0
    PB_pts = list()
    for line in MC_Partisan_Bias:
        PB_pts.append(line[0])
        sum_PB += line[0]
        sumsq_PB += line[0]**2
    n = len(MC_Partisan_Bias)
    stat_PB_mean = sum_PB / n
    # STANDARD DEVIATION
    stat_PB_sdev = math.sqrt((sumsq_PB - (sum_PB**2)/n)/(n-1))
    # Z-SCORE
    z_PB = (MC_Partisan_Bias[0][0]-stat_PB_mean)/stat_PB_sdev

    print("n = " + str(n))
    print("Initial Partisan Bias: " + str(MC_Partisan_Bias[0][0]))
    print("Average Partisan Bias Score: " + str(stat_PB_mean))
    print("Standard Deviation Partisan Bias Score: " + str(stat_PB_sdev))
    print("z-score = " + str(z_PB))
    
    plt.hist(PB_pts,bins=15)
    plt.title('Partisan Bias Histogram')
    plt.axvline(MC_Partisan_Bias[0][0], color='r', linewidth=1)
    plt.show()

    print("----------------------------------------------------------")

### BG UNIFORM ###
if test_BG_uniform == True:
    # MEAN
    sum_BGU = 0
    sumsq_BGU = 0
    BGU_pts = list()
    for line in MC_BG_Uniform:
        BGU_pts.append(line[0])
        sum_BGU += line[0]
        sumsq_BGU += line[0]**2
    n = len(MC_BG_Uniform)
    stat_BGU_mean = sum_BGU / n
    # STANDARD DEVIATION
    stat_BGU_sdev = math.sqrt((sumsq_BGU - (sum_BGU**2)/n)/(n-1))
    # Z-SCORE
    z_BGU = (MC_BG_Uniform[0][0]-stat_BGU_mean)/stat_BGU_sdev
    
    print("n = " + str(n))
    print("Initial B_G Uniform: " + str(MC_BG_Uniform[0][0]))
    print("Average B_G Uniform Score: " + str(stat_BGU_mean))
    print("Standard Deviation B_G Uniform Score: " + str(stat_BGU_sdev))
    print("z-score = " + str(z_BGU))
    
    plt.hist(BGU_pts,bins=25)
    plt.title('B_G Uniform Histogram')
    plt.axvline(MC_BG_Uniform[0][0], color='r', linewidth=1)
    plt.show()

    print("----------------------------------------------------------")

### BG MODIFIED ###
if test_BG_modified == True:
    # MEAN
    sum_BGM = 0
    sumsq_BGM = 0
    BGM_pts = list()
    for line in MC_BG_Modified:
        BGM_pts.append(line[0])
        sum_BGM += line[0]
        sumsq_BGM += line[0]**2
    n = len(MC_BG_Modified)
    stat_BGM_mean = sum_BGM / n
    # STANDARD DEVIATION
    stat_BGM_sdev = math.sqrt((sumsq_BGM - (sum_BGM**2)/n)/(n-1))
    # Z-SCORE
    z_BGM = (MC_BG_Modified[0][0]-stat_BGM_mean)/stat_BGM_sdev

    print("n = " + str(n))
    print("Initial B_G Modified: " + str(MC_BG_Modified[0][0]))
    print("Average B_G Modified Score: " + str(stat_BGM_mean))
    print("Standard Deviation B_G Modified Score: " + str(stat_BGM_sdev))
    print("z-score = " + str(z_BGM))
    
    plt.hist(BGM_pts,bins=15)
    plt.title('B_G Modified Histogram')
    plt.axvline(MC_BG_Modified[0][0], color='r', linewidth=1)
    plt.show()
    
    print("----------------------------------------------------------")
# Out:
# ----------------- DESCRIPTIVE STATISTICS -----------------
# n = 11898
# Initial Median-Mean Score: -0.0378073
# Average Median-Mean Score: 0.01287121825424686
# Standard Deviation Median-Mean Score: 0.012496561318329106
# z-score = -4.055397077907749
# ----------------------------------------------------------
# n = 11898
# Initial Variance: 0.0112919
# Average Variance Score: 0.003686370375693408
# Standard Deviation Variance Score: 0.0008473633000645882
# z-score = 8.975523985670467
# ----------------------------------------------------------
# n = 11898
# Initial Effidiency Gap: 0.261258
# Average Efficiency Gap Score: 0.18215663390485823
# Standard Deviation Efficiency Gap Score: 0.09865232856928415
# z-score = 0.8018195540066586
# ----------------------------------------------------------
# n = 11898
# Initial B_G Modified: 0.0336274
# Average B_G Modified Score: 0.024771837468481935
# Standard Deviation B_G Modified Score: 0.005352563439745969
# z-score = 1.6544526059719806
# ----------------------------------------------------------

# %%
# DISPLAY APPROPRIATE GRAPHS

print("How does the P-VALUE change with the number of steps?")

if test_median_mean == True:
    x_steps_mm = list()
    y_pvals_mm = list()
    
    for line in MC_Median_Mean:
        # Number of Steps on the x-axis
        x_steps_mm.append(line[3])
        
        # P-Value on the y-axis
        y_pvals_mm.append(line[5])
    
    # Remove the first observation since it's before we take any steps.
    assert(x_steps_mm[0]==0)
    x_steps_mm.pop(0)
    # Remove the first observation since it's when the p-value == None
    assert(y_pvals_mm[0]==None)
    y_pvals_mm.pop(0)
    
    plt.figure(figsize=(15,7))
    plt.plot(x_steps_mm, y_pvals_mm)
    plt.title('MEDIAN-MEAN: P-VALUES vs. STEPS')
    plt.show()
    
if test_variance == True:
    x_steps_v = list()
    y_pvals_v = list()
    
    for line in MC_Variance:
        # Number of Steps on the x-axis
        x_steps_v.append(line[3])
        
        # P-Value on the y-axis
        y_pvals_v.append(line[5])
    
    # Remove the first observation since it's before we take any steps.
    assert(x_steps_v[0]==0)
    x_steps_v.pop(0)
    # Remove the first observation since it's when the p-value == None
    assert(y_pvals_v[0]==None)
    y_pvals_v.pop(0)
    
    plt.figure(figsize=(15,7))
    plt.plot(x_steps_v, y_pvals_v)
    plt.title('VARIANCE: P-VALUES vs. STEPS')
    plt.show()
    
if test_efficiency_gap == True:
    x_steps_eg = list()
    y_pvals_eg = list()
    
    for line in MC_Efficiency_Gap:
        # Number of Steps on the x-axis
        x_steps_eg.append(line[3])
        
        # P-Value on the y-axis
        y_pvals_eg.append(line[5])
    
    # Remove the first observation since it's before we take any steps.
    assert(x_steps_eg[0]==0)
    x_steps_eg.pop(0)
    # Remove the first observation since it's when the p-value == None
    assert(y_pvals_eg[0]==None)
    y_pvals_eg.pop(0)
    
    plt.figure(figsize=(15,7))
    plt.plot(x_steps_eg, y_pvals_eg)
    plt.title('EFFICIENCY GAP: P-VALUES vs. STEPS')
    plt.show()
    
if test_partisan_bias == True:
    x_steps_pb = list()
    y_pvals_pb = list()
    
    for line in MC_Partisan_Bias:
        # Number of Steps on the x-axis
        x_steps_pb.append(line[3])
        
        # P-Value on the y-axis
        y_pvals_pb.append(line[5])
    
    # Remove the first observation since it's before we take any steps.
    assert(x_steps_pb[0]==0)
    x_steps_pb.pop(0)
    # Remove the first observation since it's when the p-value == None
    assert(y_pvals_pb[0]==None)
    y_pvals_pb.pop(0)
    
    plt.figure(figsize=(15,7))
    plt.plot(x_steps_pb, y_pvals_pb)
    plt.title('PARTISAN BIAS: P-VALUES vs. STEPS')
    plt.show()
    
if test_BG_uniform == True:
    x_steps_bgu = list()
    y_pvals_bgu = list()
    
    for line in MC_BG_Uniform:
        # Number of Steps on the x-axis
        x_steps_bgu.append(line[3])
        
        # P-Value on the y-axis
        y_pvals_bgu.append(line[5])
    
    # Remove the first observation since it's before we take any steps.
    assert(x_steps_bgu[0]==0)
    x_steps_bgu.pop(0)
    # Remove the first observation since it's when the p-value == None
    assert(y_pvals_bgu[0]==None)
    y_pvals_bgu.pop(0)
    
    plt.figure(figsize=(15,7))
    plt.plot(x_steps_bgu, y_pvals_bgu)
    plt.title('BG UNIFORM: P-VALUES vs. STEPS')
    plt.show()
    
if test_BG_modified == True:
    x_steps_bgm = list()
    y_pvals_bgm = list()
    
    for line in MC_BG_Modified:
        # Number of Steps on the x-axis
        x_steps_bgm.append(line[3])
        
        # P-Value on the y-axis
        y_pvals_bgm.append(line[5])
    
    # Remove the first observation since it's before we take any steps.
    assert(x_steps_bgm[0]==0)
    x_steps_bgm.pop(0)
    # Remove the first observation since it's when the p-value == None
    assert(y_pvals_bgm[0]==None)
    y_pvals_bgm.pop(0)
    
    plt.figure(figsize=(15,7))
    plt.plot(x_steps_bgm, y_pvals_bgm)
    plt.title('BG MODIFIED: P-VALUES vs. STEPS')
    plt.show()
# Out:
# How does the P-VALUE change with the number of steps?

# %%
# DISPLAY APPROPRIATE GRAPHS

print("How does the MEASURE change with the number of steps?")

if test_median_mean == True:
    y_measure_mm = list()
    for line in MC_Median_Mean:
        # Measure on the y-axis
        y_measure_mm.append(line[0]) #keep initial observation
    if x_steps_mm[0]!=0:
        x_steps_mm.insert(0,0)
    plt.figure(figsize=(30,7))
    plt.plot(x_steps_mm, y_measure_mm)
    plt.axhline(y=MC_Median_Mean[0][0],color='r')
    plt.title('MEDIAN-MEAN vs. STEPS')
    plt.show()
    
if test_variance == True:
    y_measure_v = list()
    for line in MC_Variance:
        y_measure_v.append(line[0])
    if x_steps_v[0]!=0:
        x_steps_v.insert(0,0)
    plt.figure(figsize=(30,7))
    plt.plot(x_steps_v, y_measure_v)
    plt.axhline(y=MC_Variance[0][0],color='r')
    plt.title('VARIANCE vs. STEPS')
    plt.show()
    
if test_efficiency_gap == True:
    y_measure_eg = list()
    for line in MC_Efficiency_Gap:
        y_measure_eg.append(line[0])
    if x_steps_eg[0]!=0:
        x_steps_eg.insert(0,0)
    plt.figure(figsize=(30,7))
    plt.plot(x_steps_eg, y_measure_eg)
    plt.axhline(y=MC_Efficiency_Gap[0][0],color='r')
    plt.title('EFFICIENCY GAP vs. STEPS')
    plt.show()
    
if test_partisan_bias == True:
    y_measure_pb = list()
    for line in MC_Partisan_Bias:
        y_measure_pb.append(line[0])
    if x_steps_pb[0]!=0:
        x_steps_pb.insert(0,0)
    plt.figure(figsize=(30,7))
    plt.plot(x_steps_pb, y_measure_pb)
    plt.axhline(y=MC_Partisan_Bias[0][0],color='r')
    plt.title('PARTISAN BIAS vs. STEPS')
    plt.show()
    
if test_BG_uniform == True:
    y_measure_bgu = list()
    for line in MC_BG_Uniform:
        y_measure_bgu.append(line[0])
    if x_steps_bgu[0]!=0:
        x_steps_bgu.insert(0,0)
    plt.figure(figsize=(30,7))
    plt.plot(x_steps_bgu, y_measure_bgu)
    plt.axhline(y=MC_BG_Uniform[0][0],color='r')
    plt.title('BG UNIFORM vs. STEPS')
    plt.show()
    
if test_BG_modified == True:
    y_measure_bgm = list()
    for line in MC_BG_Modified:
        y_measure_bgm.append(line[0])
    if x_steps_bgm[0]!=0:
        x_steps_bgm.insert(0,0)
    plt.figure(figsize=(30,7))
    plt.plot(x_steps_bgm, y_measure_bgm)
    plt.axhline(y=MC_BG_Modified[0][0],color='r')
    plt.title('BG MODIFIED vs. STEPS')
    plt.show()
# Out:
# How does the MEASURE change with the number of steps?

# %%
## Write a script to parse each data frame into a CSV file (step, p-value, measure, etc) as above. 
## Repeat for each output file and generate separate CSV's.
## Then write a script that shows the interesting output.
## Write something to analyze the descriptive stats for each run.
